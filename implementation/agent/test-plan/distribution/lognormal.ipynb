# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the lognormal distribution
mu = 4.5  # Controls where the peak is (in log-space)
sigma = 0.6  # Controls the skew / burstiness

n_users = 100_000
arrival_times = np.random.lognormal(mean=mu, sigma=sigma, size=n_users)

# Convert to a limited window (e.g., 0-600 seconds)
arrival_times = arrival_times[arrival_times <= 600]

# Plotting histogram to visualize and get the histogram values
counts, bin_edges = np.histogram(arrival_times, bins=20)
plt.hist(arrival_times, bins=20, color='skyblue')
plt.title("Simulated Arrival Times of Users")
plt.xlabel("Seconds since ticket drop")
plt.ylabel("User count")
plt.show()

import json
arr = []

for i in range(len(counts)):
    arr.append({
        "target": int(counts[i]),
        "duration": "30s"
    })
    print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f} seconds: {counts[i]} users")

print(json.dumps(arr))
# Out:
# Bin 1: 7.80 - 37.19 seconds: 7069 users
# Bin 2: 37.19 - 66.58 seconds: 23873 users
# Bin 3: 66.58 - 95.97 seconds: 23226 users
# Bin 4: 95.97 - 125.37 seconds: 16631 users
# Bin 5: 125.37 - 154.76 seconds: 10779 users
# Bin 6: 154.76 - 184.15 seconds: 6659 users
# Bin 7: 184.15 - 213.54 seconds: 4261 users
# Bin 8: 213.54 - 242.94 seconds: 2533 users
# Bin 9: 242.94 - 272.33 seconds: 1605 users
# Bin 10: 272.33 - 301.72 seconds: 1119 users
# Bin 11: 301.72 - 331.11 seconds: 681 users
# Bin 12: 331.11 - 360.51 seconds: 476 users
# Bin 13: 360.51 - 389.90 seconds: 320 users
# Bin 14: 389.90 - 419.29 seconds: 215 users
# Bin 15: 419.29 - 448.68 seconds: 147 users
# Bin 16: 448.68 - 478.08 seconds: 98 users
# Bin 17: 478.08 - 507.47 seconds: 86 users
# Bin 18: 507.47 - 536.86 seconds: 61 users
# Bin 19: 536.86 - 566.25 seconds: 46 users
# Bin 20: 566.25 - 595.65 seconds: 27 users
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the lognormal distribution
mu = 4.5  # Controls where the peak is (in log-space)
sigma = 0.6  # Controls the skew / burstiness

n_users = 40_000
arrival_times = np.random.lognormal(mean=mu, sigma=sigma, size=n_users)

# Convert to a limited window (e.g., 0-600 seconds)
arrival_times = arrival_times[arrival_times <= 600]

# Plotting histogram to visualize and get the histogram values
counts, bin_edges = np.histogram(arrival_times, bins=20)
plt.hist(arrival_times, bins=20, color='skyblue')
plt.title("Simulated Arrival Times of Users")
plt.xlabel("Seconds since ticket drop")
plt.ylabel("User count")
plt.show()

print("\nCounts (y values):")

import json
arr = []

for i in range(len(counts)):
    arr.append({
        "target": int(counts[i]),
        "duration": "30s"
    })
    print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f} seconds: {counts[i]} users")

print(json.dumps(arr))
# Out:
# Counts (y values):
# Bin 1: 8.33 - 37.89 seconds: 2976 users
# Bin 2: 37.89 - 67.46 seconds: 9653 users
# Bin 3: 67.46 - 97.03 seconds: 9293 users
# Bin 4: 97.03 - 126.60 seconds: 6662 users
# Bin 5: 126.60 - 156.17 seconds: 4149 users
# Bin 6: 156.17 - 185.74 seconds: 2618 users
# Bin 7: 185.74 - 215.31 seconds: 1690 users
# Bin 8: 215.31 - 244.88 seconds: 1020 users
# Bin 9: 244.88 - 274.45 seconds: 624 users
# Bin 10: 274.45 - 304.01 seconds: 423 users
# Bin 11: 304.01 - 333.58 seconds: 308 users
# Bin 12: 333.58 - 363.15 seconds: 196 users
# Bin 13: 363.15 - 392.72 seconds: 129 users
# Bin 14: 392.72 - 422.29 seconds: 67 users
# Bin 15: 422.29 - 451.86 seconds: 55 users
# Bin 16: 451.86 - 481.43 seconds: 41 users
# Bin 17: 481.43 - 511.00 seconds: 30 users
# Bin 18: 511.00 - 540.57 seconds: 17 users
# Bin 19: 540.57 - 570.13 seconds: 14 users
# Bin 20: 570.13 - 599.70 seconds: 7 users
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the lognormal distribution
mu = 4.5  # Controls where the peak is (in log-space)
sigma = 0.6  # Controls the skew / burstiness

n_users = 12_000
arrival_times = np.random.lognormal(mean=mu, sigma=sigma, size=n_users)

# Convert to a limited window (e.g., 0-600 seconds)
arrival_times = arrival_times[arrival_times <= 600]

# Plotting histogram to visualize and get the histogram values
counts, bin_edges = np.histogram(arrival_times, bins=20)
plt.hist(arrival_times, bins=20, color='skyblue')
plt.title("Simulated Arrival Times of Users")
plt.xlabel("Seconds since ticket drop")
plt.ylabel("User count")
plt.show()

print("\nCounts (y values):")

import json
arr = []

for i in range(len(counts)):
    arr.append({
        "target": int(counts[i]),
        "duration": "30s"
    })
    print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f} seconds: {counts[i]} users")

print(json.dumps(arr))
# Out:
# Counts (y values):
# Bin 1: 5.38 - 35.03 seconds: 743 users
# Bin 2: 35.03 - 64.69 seconds: 2792 users
# Bin 3: 64.69 - 94.34 seconds: 2922 users
# Bin 4: 94.34 - 124.00 seconds: 2005 users
# Bin 5: 124.00 - 153.66 seconds: 1282 users
# Bin 6: 153.66 - 183.31 seconds: 838 users
# Bin 7: 183.31 - 212.97 seconds: 502 users
# Bin 8: 212.97 - 242.63 seconds: 323 users
# Bin 9: 242.63 - 272.28 seconds: 220 users
# Bin 10: 272.28 - 301.94 seconds: 124 users
# Bin 11: 301.94 - 331.60 seconds: 77 users
# Bin 12: 331.60 - 361.25 seconds: 45 users
# Bin 13: 361.25 - 390.91 seconds: 51 users
# Bin 14: 390.91 - 420.57 seconds: 30 users
# Bin 15: 420.57 - 450.22 seconds: 16 users
# Bin 16: 450.22 - 479.88 seconds: 7 users
# Bin 17: 479.88 - 509.54 seconds: 8 users
# Bin 18: 509.54 - 539.19 seconds: 4 users
# Bin 19: 539.19 - 568.85 seconds: 2 users
# Bin 20: 568.85 - 598.51 seconds: 3 users
# ...
