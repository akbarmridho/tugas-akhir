# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the lognormal distribution
mu = 4.5  # Controls where the peak is (in log-space)
sigma = 0.6  # Controls the skew / burstiness

n_users = 100_000
arrival_times = np.random.lognormal(mean=mu, sigma=sigma, size=n_users)

# Convert to a limited window (e.g., 0-600 seconds)
arrival_times = arrival_times[arrival_times <= 600]

# Plotting histogram to visualize and get the histogram values
counts, bin_edges = np.histogram(arrival_times, bins=20)
plt.hist(arrival_times, bins=20, color='skyblue')
plt.title("Simulated Arrival Times of Users")
plt.xlabel("Seconds since ticket drop")
plt.ylabel("User count")
plt.show()

import json
arr = []

for i in range(len(counts)):
    arr.append({
        "target": int(counts[i]),
        "duration": "30s"
    })
    print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f} seconds: {counts[i]} users")

print(json.dumps(arr))
# Out:
# Bin 1: 6.76 - 36.41 seconds: 6606 users
# Bin 2: 36.41 - 66.06 seconds: 23664 users
# Bin 3: 66.06 - 95.71 seconds: 23777 users
# Bin 4: 95.71 - 125.36 seconds: 16826 users
# Bin 5: 125.36 - 155.01 seconds: 10861 users
# Bin 6: 155.01 - 184.66 seconds: 6789 users
# Bin 7: 184.66 - 214.31 seconds: 4138 users
# Bin 8: 214.31 - 243.96 seconds: 2559 users
# Bin 9: 243.96 - 273.61 seconds: 1622 users
# Bin 10: 273.61 - 303.26 seconds: 1069 users
# Bin 11: 303.26 - 332.91 seconds: 682 users
# Bin 12: 332.91 - 362.56 seconds: 446 users
# Bin 13: 362.56 - 392.21 seconds: 283 users
# Bin 14: 392.21 - 421.86 seconds: 193 users
# Bin 15: 421.86 - 451.51 seconds: 122 users
# Bin 16: 451.51 - 481.16 seconds: 102 users
# Bin 17: 481.16 - 510.81 seconds: 71 users
# Bin 18: 510.81 - 540.46 seconds: 61 users
# Bin 19: 540.46 - 570.11 seconds: 34 users
# Bin 20: 570.11 - 599.76 seconds: 22 users
# [{"target": 6606, "duration": "30s"}, {"target": 23664, "duration": "30s"}, {"target": 23777, "duration": "30s"}, {"target": 16826, "duration": "30s"}, {"target": 10861, "duration": "30s"}, {"target": 6789, "duration": "30s"}, {"target": 4138, "duration": "30s"}, {"target": 2559, "duration": "30s"}, {"target": 1622, "duration": "30s"}, {"target": 1069, "duration": "30s"}, {"target": 682, "duration": "30s"}, {"target": 446, "duration": "30s"}, {"target": 283, "duration": "30s"}, {"target": 193, "duration": "30s"}, {"target": 122, "duration": "30s"}, {"target": 102, "duration": "30s"}, {"target": 71, "duration": "30s"}, {"target": 61, "duration": "30s"}, {"target": 34, "duration": "30s"}, {"target": 22, "duration": "30s"}]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the lognormal distribution
mu = 4.5  # Controls where the peak is (in log-space)
sigma = 0.6  # Controls the skew / burstiness

n_users = 50_000
arrival_times = np.random.lognormal(mean=mu, sigma=sigma, size=n_users)

# Convert to a limited window (e.g., 0-600 seconds)
arrival_times = arrival_times[arrival_times <= 600]

# Plotting histogram to visualize and get the histogram values
counts, bin_edges = np.histogram(arrival_times, bins=20)
plt.hist(arrival_times, bins=20, color='skyblue')
plt.title("Simulated Arrival Times of Users")
plt.xlabel("Seconds since ticket drop")
plt.ylabel("User count")
plt.show()

print("\nCounts (y values):")

import json
arr = []

for i in range(len(counts)):
    arr.append({
        "target": int(counts[i]),
        "duration": "30s"
    })
    print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f} seconds: {counts[i]} users")

print(json.dumps(arr))
# Out:
# Counts (y values):
# Bin 1: 8.87 - 38.29 seconds: 3964 users
# Bin 2: 38.29 - 67.72 seconds: 11850 users
# Bin 3: 67.72 - 97.15 seconds: 11500 users
# Bin 4: 97.15 - 126.57 seconds: 8329 users
# Bin 5: 126.57 - 156.00 seconds: 5280 users
# Bin 6: 156.00 - 185.43 seconds: 3244 users
# Bin 7: 185.43 - 214.85 seconds: 2100 users
# Bin 8: 214.85 - 244.28 seconds: 1300 users
# Bin 9: 244.28 - 273.71 seconds: 825 users
# Bin 10: 273.71 - 303.13 seconds: 515 users
# Bin 11: 303.13 - 332.56 seconds: 354 users
# Bin 12: 332.56 - 361.99 seconds: 235 users
# Bin 13: 361.99 - 391.41 seconds: 146 users
# Bin 14: 391.41 - 420.84 seconds: 115 users
# Bin 15: 420.84 - 450.27 seconds: 74 users
# Bin 16: 450.27 - 479.69 seconds: 55 users
# Bin 17: 479.69 - 509.12 seconds: 35 users
# Bin 18: 509.12 - 538.55 seconds: 18 users
# Bin 19: 538.55 - 567.97 seconds: 13 users
# Bin 20: 567.97 - 597.40 seconds: 9 users
# [{"target": 3964, "duration": "30s"}, {"target": 11850, "duration": "30s"}, {"target": 11500, "duration": "30s"}, {"target": 8329, "duration": "30s"}, {"target": 5280, "duration": "30s"}, {"target": 3244, "duration": "30s"}, {"target": 2100, "duration": "30s"}, {"target": 1300, "duration": "30s"}, {"target": 825, "duration": "30s"}, {"target": 515, "duration": "30s"}, {"target": 354, "duration": "30s"}, {"target": 235, "duration": "30s"}, {"target": 146, "duration": "30s"}, {"target": 115, "duration": "30s"}, {"target": 74, "duration": "30s"}, {"target": 55, "duration": "30s"}, {"target": 35, "duration": "30s"}, {"target": 18, "duration": "30s"}, {"target": 13, "duration": "30s"}, {"target": 9, "duration": "30s"}]
